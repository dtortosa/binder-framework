# %%
##import required packages
#for plotting
import matplotlib as mpl
import matplotlib.pyplot as plt
#for data procesing and numerical operations
import pandas as pd
import numpy as np
#for date processing
from datetime import datetime

# %%
##read data
energy_data = pd.read_csv("data/Value_of_Energy_Cost_Savings_Program_Savings_for_Businesses_-_FY2020.csv")
energy_data
# Out:
#                                  Company Name    company contact  \
# 0                              1 State Street      David Neiburg
# 1                              100 Church LLC  Edward A. Carroll
# 2                        100 Wall Investments       Jerry Branam
# 3                 1-10 Bush Terminal Owner LP     Andrew Kimball
# 4    120 Broadway Acquisitions JV, LLC (Ldmk)        Carl Letich
# ..                                        ...                ...
# 445                         WONTON FOOD, INC.         DONALD LAU
# 446                                Wood Works       Gordon Brawm
# 447           WorldWide Plumbing Supply, Inc.    Surie Lefkowitz
# 448                         WUD Furniture LLC     Keren Springer
# 449                       Wurtec Incorporated          Bill Popp
#
#                  company email company phone                Address  \
# 0       eskoblo@energyspec.com    7186779077          1114 Avenue J
# 1                          NaN    2125663000      100 Church Street
# 2                          NaN    2122487160         96 Wall Street
# 3    akimball@industrycity.com    3474178429  220 36th St, Suite 2A
# 4        clettich@silvprop.com    2124064020           120 Broadway
# ..                         ...           ...                    ...
# 445   donaldlau@wontonfood.com    7186286868  220-222  MOORE STREET
# 446       brawnworks@gmail.com    9179404950        162 Cook Street
# 447           sheidya@wwps.com    7188533002        125 Lake Avenue
# 448     keren@wudfurniture.com    7184867952   1102 Atlantic Avenue
# 449       bill.popp@wurtec.com    4197261066      31-50 31st Street
#
#                  City State  Postcode                          Industry  \
# 0            Brooklyn    NY     11230                        Commercial
# 1                  NY    NY     10007                        Commercial
# 2            New York    NY     10005                          Landlord
# 3            Brooklyn    NY     11232                          Landlord
# 4            New York    NY     10271                        Commercial
# ..                ...   ...       ...                               ...
# 445          Brooklyn    NY     11206                     Manufacturing
# 446          Brooklyn    NY     11206                     Manufacturing
# 447     Staten Island    NY     10303                     Manufacturing
# 448          Brooklyn    NY     11238                     Manufacturing
# 449  Lond Island City    NY     11106  Wholesale/Warehouse/Distribution
#
#                                         Industry descr  ...  \
# 0                                    35 story building  ...
# 1                                            21 Floors  ...
# 2                                                  NaN  ...
# 3    Special Eligible Premises for eligible businesses  ...
# 4                                                  NaN  ...
# ..                                                 ...  ...
# 445                          MFG. PASTA, EGGROLL SKINS  ...
# 446                        Installer of wood furniture  ...
# 447      Plumbing Fixtures, Parts & Supplies, Plumbers  ...
# 448  We make handcrafted furniture, surfaces, lighting  ...
# 449                         Elevator  tooling products  ...
#
#     Savings from beginning receiving benefits        Borough   Latitude  \
# 0                                      349.78       Brooklyn  40.624784
# 1                                  4423698.05       New York  40.712968
# 2                                  1814542.62       New York  40.705052
# 3                                     6755.31       Brooklyn  40.656061
# 4                                  3293055.08       New York  40.708546
# ..                                        ...            ...        ...
# 445                                 965843.58       Brooklyn  40.704425
# 446                                   3585.40       Brooklyn  40.702869
# 447                                  20487.73  Staten Island  40.633518
# 448                                  12287.32       Brooklyn  40.679518
# 449                                      0.00         Queens  40.763148
#
#      Longitude Community Board  Council District  Census Tract        BIN  \
# 0   -73.964920           314.0              44.0         534.0  3179818.0
# 1   -74.009490           101.0               1.0          21.0  1001409.0
# 2   -74.007199           101.0               1.0           7.0  1000875.0
# 3   -74.007334           307.0              38.0           2.0  3398687.0
# 4   -74.011041           101.0               1.0           7.0  1001026.0
# ..         ...             ...               ...           ...        ...
# 445 -73.936010           301.0              34.0         485.0  3071539.0
# 446 -73.936466           301.0              34.0         485.0  3071625.0
# 447 -74.150942           501.0              49.0         239.0  5107122.0
# 448 -73.956819           308.0              35.0         305.0  3027572.0
# 449 -73.924442           401.0              22.0          61.0  4007562.0
#
#               BBL                                                NTA
# 0    3.067130e+09                                            Midwood
# 1    1.001250e+09             SoHo-TriBeCa-Civic Center-Little Italy
# 2    1.000380e+09                  Battery Park City-Lower Manhattan
# 3    3.006950e+09                                   Sunset Park West
# 4    1.000478e+09                  Battery Park City-Lower Manhattan
# ..            ...                                                ...
# 445  3.031090e+09                                     Bushwick South
# 446  3.031230e+09                                     Bushwick South
# 447  5.011610e+09  Mariner's Harbor-Arlington-Port Ivory-Granitev...
# 448  3.011260e+09                                Crown Heights North
# 449  4.005890e+09                                            Astoria
#
# [450 rows x 26 columns]

# %%
##read results
energy_results = pd.read_csv("results.csv", index_col=0) 
    #original row names at first column
energy_results
# Out:
#                                                  NTA  Average Savings  \
# 2                                Crown Heights North      4036.298889
# 9                                      East New York     48433.093333
# 12                                    Manhattanville      2760.888889
# 17                                     College Point     17159.372857
# 19                                    Bushwick South     26140.455000
# 20                            Mott Haven-Port Morris     17843.937857
# 23              Hunters Point-Sunnyside-West Maspeth     23931.398933
# 28                                          Steinway     11227.155714
# 37                 Battery Park City-Lower Manhattan    469890.796667
# 38          Carroll Gardens-Columbia Street-Red Hook     24337.390000
# 40                                 East Williamsburg     13990.626364
# 48            SoHo-TriBeCa-Civic Center-Little Italy     37214.024000
# 49  DUMBO-Vinegar Hill-Downtown Brooklyn-Boerum Hill     59950.340000
# 50                                       Hunts Point     39246.016154
# 51                        park-cemetery-etc-Brooklyn     14327.419333
# 64          Queensbridge-Ravenswood-Long Island City     61830.770625
# 67                                           Maspeth      6658.283333
# 72                                  Sunset Park West     14316.976875
# 74              Springfield Gardens South-Brookville     17757.662000
# 78                                        Greenpoint      9753.649286
#
#     Total Jobs
# 2          0.0
# 9         15.0
# 12         0.0
# 17         2.0
# 19        10.0
# 20        10.0
# 23         0.0
# 28        20.0
# 37         0.0
# 38         0.0
# 40         0.0
# 48         0.0
# 49         0.0
# 50        12.0
# 51         0.0
# 64         0.0
# 67        10.0
# 72         0.0
# 74         0.0
# 78         0.0

# %%
##scatter job vs. savings standardad scale

#open the plot
fig, ax = plt.subplots(figsize=(4, 4))

#select the data and presentation
plt.scatter(x="Average Savings", y="Total Jobs", data=energy_results, s=40, alpha=1)
    #s is for point size; alpha is for color contrast; c is for color

#set the axis labels
ax.set_xlabel("Average Savings")
ax.set_ylabel("Total Jobs")

#set title
ax.set_title("Jobs versus Savings")
# Out:
# Text(0.5, 1.0, 'Jobs versus Savings')

# %%
##scatter job vs. savings log scale

#open the plot
fig, ax = plt.subplots(figsize=(4, 4))

#define the variables to plot
x = np.log(energy_results["Average Savings"])
y = energy_results["Total Jobs"]

#select the data and presentation
plt.scatter(x=x, y=y, s=40, alpha=1)
    #s is for point size; alpha is for color contrast; c is for color

#set the axis labels
ax.set_xlabel("Average Savings")
ax.set_ylabel("Total Jobs")

#set title
ax.set_title("Jobs versus Savings \n log scale")
# Out:
# Text(0.5, 1.0, 'Jobs versus Savings \n log scale')

# %%
##histogram savings log scale

#open the plot
fig, ax = plt.subplots(figsize=(4, 4))

#define the variable
savings_log = np.log(energy_results["Average Savings"])

#plot the histogram
n, bins, patches = plt.hist(savings_log, bins='auto', color='#0504aa', alpha=0.7, rwidth=0.85)

#set axis labels
ax.set_xlabel("Total savings")
ax.set_ylabel("Frequency")

#set title
ax.set_title("Histogram average savings \n log scale")
# Out:
# Text(0.5, 1.0, 'Histogram average savings \n log scale')

# %%
##calculate total jobs across months

#look for the date column
print([col for col in energy_data.columns])

#list dates
list_dates = list(energy_data["Effective Date"])

#list of months
list_months = []
for date in list_dates: #for each date
    
    #split by "/"
    dates_splitted = date.split("/")
    
    #select the month and append
    list_months.append(dates_splitted[0])
    
    #run this instead of the preivous line in case you want to calculate jobs per each month and year, i.e., jan-2020, jan-2021....
    #list_months.append(("/".join([dates_splitted[0], dates_splitted[-1]])))

#add as a new column
energy_data["Effective Month"] = list_months

#unique months
list_months = list(set(energy_data["Effective Month"]))

#order by month
list_months.sort(key=lambda date: datetime.strptime(date, "%m"))
    #convert date strings to datetime object and use it to sort

#create df to save results
results = pd.DataFrame(list_months)
results = results.rename(columns={0: "Effective Month"})
results["Total Jobs"] = ""

#calculate the total number of jobs created in each month
for month in list_months:
    
    #extract the job created in date
    jobs_selected_date = energy_data.loc[energy_data["Effective Month"] == month, "Job created"]
    
    #sum
    total_jobs = np.nansum(jobs_selected_date)
        #use np.nan just in case there are nan
    
    #save
    results.loc[results["Effective Month"] == month, "Total Jobs"] = total_jobs


#see results
results
# Out:
# ['Company Name', 'company contact', 'company email', 'company phone', 'Address', 'City', 'State', 'Postcode', 'Industry', 'Industry descr', 'Company Type', 'Current fulltime', 'Job created', 'Job retain', 'Effective Date', 'Total Savings', 'Savings from beginning receiving benefits', 'Borough', 'Latitude', 'Longitude', 'Community Board', 'Council District', 'Census Tract', 'BIN', 'BBL', 'NTA']
#    Effective Month Total Jobs
# 0               01          0
# 1               02         27
# 2               03         20
# 3               04          2
# 4               05          2
# 5               06         63
# 6               07         20
# 7               08          0
# 8               09          0
# 9               10          0
# 10              11          5
# 11              12         10

# %%
##plot the results

#open the plot
fig, ax = plt.subplots(figsize=(4, 4))

#select the data and presentation
plt.plot("Effective Month", "Total Jobs", data=results)
    #s is for point size; alpha is for color contrast; c is for color

#set the axis labels
ax.set_xlabel("Month")
ax.set_ylabel("Total Jobs")

#set title
ax.set_title("Jobs across Months")
# Out:
# Text(0.5, 1.0, 'Jobs across Months')
